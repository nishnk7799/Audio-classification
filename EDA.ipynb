# %%
##### Audio Classification Using Machine Learning
#####dataset url https://urbansounddataset.weebly.com/urbansound8k.html

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from librosa) (21.0)
# Collecting pooch>=1.0
#   Downloading pooch-1.4.0-py3-none-any.whl (51 kB)
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (689 kB)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from librosa) (4.4.0)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from librosa) (1.16.4)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from librosa) (0.21.2)
# Collecting joblib>=0.14
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting numba>=0.43.0
#   Downloading numba-0.53.1-cp37-cp37m-win_amd64.whl (2.3 MB)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from librosa) (1.2.1)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
# Requirement already satisfied: setuptools in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from numba>=0.43.0->librosa) (50.3.2)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp37-cp37m-win_amd64.whl (16.0 MB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from packaging>=20.0->librosa) (2.4.0)
# Requirement already satisfied: requests in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from pooch>=1.0->librosa) (2.23.0)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: six>=1.3 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from resampy>=0.2.2->librosa) (1.12.0)
# Collecting cffi>=1.0
#   Downloading cffi-1.14.6-cp37-cp37m-win_amd64.whl (178 kB)
# Collecting pycparser
#   Using cached pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from requests->pooch>=1.0->librosa) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nvish\appdata\local\programs\python\python37\lib\site-packages (from requests->pooch>=1.0->librosa) (2.9)
# Building wheels for collected packages: audioread, resampy
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23147 sha256=75cc70598042f698e677d53bf1be4f45701f4dd2a0f5bf0478b2263dde5508d0
#   Stored in directory: c:\users\nvish\appdata\local\pip\cache\wheels\ba\7b\eb\213741ccc0678f63e346ab8dff10495995ca3f426af87b8d88
#   Building wheel for resampy (setup.py): started
#   Building wheel for resampy (setup.py): finished with status 'done'
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320724 sha256=ff806a5a28c9ba638488e544b2c24c9e3fcbdae93fef74a803b7c90027885a5a
#   Stored in directory: c:\users\nvish\appdata\local\pip\cache\wheels\a0\18\0a\8ad18a597d8333a142c9789338a96a6208f1198d290ece356c
# Successfully built audioread resampy
# Installing collected packages: pycparser, llvmlite, numba, joblib, cffi, appdirs, soundfile, resampy, pooch, audioread, librosa
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.13.2
#     Uninstalling joblib-0.13.2:
#       Successfully uninstalled joblib-0.13.2
# Successfully installed appdirs-1.4.4 audioread-2.1.9 cffi-1.14.6 joblib-1.0.1 librosa-0.8.1 llvmlite-0.36.0 numba-0.53.1 pooch-1.4.0 pycparser-2.20 resampy-0.2.2 soundfile-0.10.3.post1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'UrbanSound8K/aud.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
plt.figure(figsize=(14,5))
data, sample_rate = librosa.load(filename)
librosa.display.waveplot(data, sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wav_sample_rate, wave_audio = wav.read(filename)

# %%
wav_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([2914, 2884, 2817, ..., 2416, 2398, 2426], dtype=int16)

# %%
data
# Out:
# array([0.06549855, 0.092955  , 0.07404263, ..., 0.07380109, 0.07230776,
#        0.07765508], dtype=float32)

# %%
import pandas as pd

metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head(5)
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
### Ckeck for Imbalance data
metadata['class'].value_counts()
# Out:
# street_music        1000
# children_playing    1000
# air_conditioner     1000
# engine_idling       1000
# dog_bark            1000
# drilling            1000
# jackhammer          1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
